# %% [markdown]
# # Default notebook
#
# This default notebook is executed using Databricks Workflows as defined in resources/randy_pitcher_workspace.job.yml.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# get UC iceberg catalog details
UC_CATALOG = 'randy_pitcher_workspace'
UC_DATABRICKS_URL = dbutils.notebook.entry_point.getDbutils().notebook().getContext().browserHostName().get()
UC_CATALOG_URI = f'https://{UC_DATABRICKS_URL}/api/2.1/unity-catalog/iceberg-rest'
UC_CREDENTIAL = (
  dbutils.notebook.entry_point.getDbutils()
    .notebook()
    .getContext()
    .apiToken()
    .getOrElse(None)
)


spark.sql("""
insert into randy_pitcher_workspace.default.space_stuff_iceberg 
   (object_name, type, distance_from_earth_lightyears, diameter_km, year_discovered)
  values 
 ('The Moon 🌕', 'Satellite', 0.00000257, 3474.8, -4000)
""")
